# %%
# trying out unicode replacement in file
# https://docs.python.org/3/howto/unicode.html

# %%
str1 = "123" + "\N{GREEK CAPITAL LETTER DELTA}" + "456"  # Using the character name

# %%
print(str1)
# Out:
# 123Δ456
